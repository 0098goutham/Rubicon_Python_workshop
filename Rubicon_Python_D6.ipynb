# %% [markdown]
# # DAY 6

# %%
import pandas as pd 
df=pd.read_csv('forbes_billionaires.csv')
df
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df.head()
# Out:
#                        Name  NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos     177.0  United States         Amazon     1
# 1                 Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family     150.0         France           LVMH     3
# 3                Bill Gates     124.0  United States      Microsoft     4
# 4           Mark Zuckerberg      97.0  United States       Facebook     5
#
#     Age              Residence    Citizenship           Status  Children  \
# 0  57.0    Seattle, Washington  United States  In Relationship       4.0
# 1  49.0          Austin, Texas  United States  In Relationship       7.0
# 2  72.0          Paris, France         France          Married       5.0
# 3  65.0     Medina, Washington  United States         Divorced       3.0
# 4  36.0  Palo Alto, California  United States          Married       2.0
#
#                                            Education Self_made
# ...

# %%
df.isnull().sum()
# Out:
# Name              0
# NetWorth          0
# Country           0
# Source            0
# Rank              0
# Age             125
# Residence        40
# Citizenship      16
# Status          665
# Children       1203
# Education      1346
# Self_made        18
# dtype: int64

# %%
df.loc[0,"Name"]
# Out:
# 'Jeff Bezos'

# %%
df.dtypes
# Out:
# Name            object
# NetWorth       float64
# Country         object
# Source          object
# Rank             int64
# Age            float64
# Residence       object
# Citizenship     object
# Status          object
# Children       float64
# Education       object
# Self_made       object
# dtype: object

# %%
df["Children"]
# Out:
# 0       4.0
# 1       7.0
# 2       5.0
# 3       3.0
# 4       2.0
#        ...
# 2750    NaN
# 2751    NaN
# 2752    NaN
# 2753    NaN
# 2754    NaN
# Name: Children, Length: 2755, dtype: float64

# %%
df
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df
# Out:
#                           Name  NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df.shape
# Out:
# (2755, 12)

# %%
df["address"]
# Out:
# 0       USA
# 1       USA
# 2       USA
# 3       USA
# 4       USA
#        ...
# 2750    USA
# 2751    USA
# 2752    USA
# 2753    USA
# 2754    USA
# Name: address, Length: 2755, dtype: object

# %%
df[df["Age"]>50]
# Out:
#                           Name  NetWorth        Country              Source  \
# 0                   Jeff Bezos     177.0  United States              Amazon
# 2     Bernard Arnault & family     150.0         France                LVMH
# 3                   Bill Gates     124.0  United States           Microsoft
# 5               Warren Buffett      96.0  United States  Berkshire Hathaway
# 6                Larry Ellison      93.0  United States            software
# ...                        ...       ...            ...                 ...
# 2749                Yu De-Chao       1.0  United States     pharmaceuticals
# 2751             Zhang Yuqiang       1.0          China          Fiberglass
# 2752             Zhao Meiguang       1.0          China         gold mining
# 2753            Zhong Naixiong       1.0          China        conglomerate
# 2754           Zhou Wei family       1.0          China            Software
#
# ...

# %%
df=df.rename(columns={"Country":"Nation","City":"Residence"})

# %%
df["Nation"]+df["Residence"]
# Out:
# 0         United StatesSeattle, Washington
# 1               United StatesAustin, Texas
# 2                      FranceParis, France
# 3          United StatesMedina, Washington
# 4       United StatesPalo Alto, California
#                        ...
# 2750                  ChinaHangzhou, China
# 2751                 ChinaTongxiang, China
# 2752                     ChinaJilin, China
# 2753                    ChinaFoshan, China
# 2754                  ChinaShanghai, China
# Length: 2755, dtype: object

# %%
df
# Out:
#                           Name  NetWorth         Nation         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df[df["Nation"]=="India"]
# Out:
#                        Name  NetWorth Nation                       Source  \
# 9             Mukesh Ambani      84.5  India                  diversified
# 23    Gautam Adani & family      50.5  India  infrastructure, commodities
# 71               Shiv Nadar      23.5  India            software services
# 116      Radhakishan Damani      16.5  India          retail, investments
# 122              Uday Kotak      15.9  India                      banking
# ...                     ...       ...    ...                          ...
# 2683       Ramesh Kumar Dua       1.0  India                     footwear
# 2698          Ashok Kajaria       1.0  India                        tiles
# 2699      T.S. Kalyanaraman       1.0  India                      jewelry
# 2712          Rafique Malik       1.0  India                     footwear
# 2715         Mofatraj Munot       1.0  India                  real estate
#
#       Rank   Age         Residence Citizenship   Status  Children  \
# ...

# %%
df.groupby("Nation")["Age"].max()
# Out:
# Nation
# Algeria           77.0
# Argentina         94.0
# Australia         90.0
# Austria           92.0
# Belgium           74.0
#                   ...
# United Kingdom    95.0
# United States     99.0
# Venezuela         61.0
# Vietnam           61.0
# Zimbabwe          60.0
# Name: Age, Length: 70, dtype: float64

# %%
#df["Age"].mean()
#df["Age"].min()
df["Age"].max()
#df["Age"].std()
#df["Age"].median()
# Out:
# 99.0

# %%
df[df["Age"]<30]
# Out:
#                       Name  NetWorth         Nation             Source  Rank  \
# 274      Sam Bankman-Fried       8.7  United States     cryptocurrency   274
# 661   Gustav Magnar Witzoe       4.4         Norway       fish farming   655
# 940    Kevin David Lehmann       3.3        Germany         drugstores   925
# 1328         Jonathan Kwok       2.4      Hong Kong        Real Estate  1299
# 1338        Austin Russell       2.4  United States                  ★  1299
# 1596             Andy Fang       2.0  United States  food delivery app  1580
# 1645          Stanley Tang       2.0  United States  food delivery app  1580
# 2122           Wang Zelong       1.5          China          chemicals  2035
# 2143    Alexandra Andresen       1.4         Norway        investments  2141
# 2144    Katharina Andresen       1.4         Norway        investments  2141
#
#        Age                  Residence    Citizenship   Status  Children  \
# ...

# %%
df["Nation"].value_counts().head(5)
# Out:
# Nation
# United States    724
# China            626
# India            140
# Germany          136
# Russia           118
# Name: count, dtype: int64

# %%
df
# Out:
#                           Name  NetWorth         Nation         Source  Rank  \
# 0                   Jeff Bezos     177.0  United States         Amazon     1
# 1                    Elon Musk     151.0  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family     150.0         France           LVMH     3
# 3                   Bill Gates     124.0  United States      Microsoft     4
# 4              Mark Zuckerberg      97.0  United States       Facebook     5
# ...                        ...       ...            ...            ...   ...
# 2750         Daniel Yong Zhang       1.0          China     e-commerce  2674
# 2751             Zhang Yuqiang       1.0          China     Fiberglass  2674
# 2752             Zhao Meiguang       1.0          China    gold mining  2674
# 2753            Zhong Naixiong       1.0          China   conglomerate  2674
# 2754           Zhou Wei family       1.0          China       Software  2674
#
# ...

# %%
df["Self_made"].value_counts()
# Out:
# Self_made
# True     1960
# False     777
# Name: count, dtype: int64
